# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
import os
base_dir = os.path.abspath(os.getcwd())
# Build paths relative to the repo root (assumes notebook runs from repo root)
data_root = os.path.join(base_dir, "data", "AI-CA-Data")
train_dir = os.path.join(data_root, "train")
valid_dir = os.path.join(data_root, "valid")
test_dir  = os.path.join(data_root, "test")

# Quick diagnostics
print("cwd:", base_dir)
print("train_dir:", train_dir)
print("train_dir exists:", os.path.isdir(train_dir))
print("valid_dir exists:", os.path.isdir(valid_dir))
print("test_dir exists :", os.path.isdir(test_dir))

train_dir, valid_dir, test_dir
# Out:
# ('../data/AI-CA-Data/train',
#  '../data/AI-CA-Data/valid',
#  '../data/AI-CA-Data/test')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (224, 224)
batch_size = 32

# Training data with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    rotation_range=20,
    zoom_range=0.2
)

# Validation data (no augmentation)
valid_datagen = ImageDataGenerator(
    rescale=1./255
)

train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

valid_data = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 0 images belonging to 70 classes.
# Found 75 images belonging to 70 classes.

# %%
import os, pathlib, glob

# show current working directory used by the kernel
print("cwd:", os.getcwd())

# print how your train_dir resolves and whether it exists
train_dir = "../data/AI-CA-Data/train"
print("train_dir (as set):", train_dir)
print("train_dir (absolute):", os.path.abspath(train_dir))
print("exists:", os.path.exists(train_dir))
print("isdir:", os.path.isdir(train_dir))

# list top-level entries under the resolved path (if any)
try:
    print("entries:", os.listdir(train_dir)[:20])
except Exception as e:
    print("listdir error:", e)

# count image files recursively (common extensions)
imgs = glob.glob(os.path.join(os.path.abspath(train_dir), "**", "*.jpg"), recursive=True) \
     + glob.glob(os.path.join(os.path.abspath(train_dir), "**", "*.jpeg"), recursive=True) \
     + glob.glob(os.path.join(os.path.abspath(train_dir), "**", "*.png"), recursive=True)
print("found images (recursive):", len(imgs))
# Out:
# cwd: c:\Users\okeef\DogBreedClassifier\notebooks
# train_dir (as set): ../data/AI-CA-Data/train
# train_dir (absolute): c:\Users\okeef\DogBreedClassifier\data\AI-CA-Data\train
# exists: True
# isdir: True
# entries: ['Afghan', 'African Wild Dog', 'Airedale', 'American Hairless', 'American Spaniel', 'Basenji', 'Basset', 'Beagle', 'Bearded Collie', 'Bermaise', 'Bichon Frise', 'Blenheim', 'Bloodhound', 'Bluetick', 'Border Collie', 'Borzoi', 'Boston Terrier', 'Boxer', 'Bull Mastiff', 'Bull Terrier']
# found images (recursive): 0
